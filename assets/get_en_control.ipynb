# %%
import pandas as pd

# %%
import pandas as pd
data = pd.read_csv('../assets\csv_data\english_translation_set_pl.csv')

json_data = data.to_json(orient='records')


with open('data_control_pl.json', 'w') as json_file:
    json_file.write(json_data)
